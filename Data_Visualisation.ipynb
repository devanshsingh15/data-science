# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x=np.linspace(0,10)
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x),color='red')

# %%
plt.plot(x,np.sin(x), linestyle='dotted', color='red')

# %%
plt.plot(x,np.cos(x),'yo')
plt.show()

# %%
plt.plot(x,np.cos(x),'yd')
plt.show()

# %%
plt.plot(x,np.cos(x),'yv')
plt.show()

# %%
plt.plot(x,np.cos(x),'y*')
plt.show()

# %%
plt.plot(x,np.cos(x),'y-')
plt.show()

# %%
guests=[19,22,20,26]
subscribers=[105,103,98,93]
plt.plot([guests,subscribers])

# %%
langs=['C','C++','Java','Python','PHP']
students=[23,17,35,29,12]
plt.bar(langs,students,width=0.75,color='orange')
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
collectn_1=np.random.normal(100,10,200)
collectn_2=np.random.normal(80,30,200)
collectn_3=np.random.normal(90,20,200)
collectn_4=np.random.normal(70,25,200)
data=[collectn_1,collectn_2,collectn_3,collectn_4]
bp=plt.boxplot(data)
plt.show()

# %%
x=[1,2,3,4,5,6,7,8]
y=[5,2,4,2,1,4,5,2]
plt.scatter(x,y,color='purple',marker='D',label='Graph')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph between X and Y')
plt.legend(loc='upper right')
