# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('C:\\Users\\Devansh\\OneDrive\\Desktop\\DOMAIN\\titanic_train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=train,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=train,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=train,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Pclass',y='Age',data=train,palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
import pandas as pd
import numpy as np
data={'student':['jack','mike','rohan','zubair'],'year':[1,2,3,1],'marks':[9.8,6.7,8.0,9.9]}
df=pd.DataFrame(data)
df
# Out:
#   student  year  marks
# 0    jack     1    9.8
# 1    mike     2    6.7
# 2   rohan     3    8.0
# 3  zubair     1    9.9

# %%
df['student'].str.upper()
# Out:
# 0      JACK
# 1      MIKE
# 2     ROHAN
# 3    ZUBAIR
# Name: student, dtype: object

# %%
l=[{'student':'Jack','year':1,'marks':9.8},{'student':'Mike','year':2,'marks':6.7}]
pd.DataFrame(l)
# Out:
#   student  year  marks
# 0    Jack     1    9.8
# 1    Mike     2    6.7

# %%
l=[{'student':'Jack','year':1,'marks':9.8},{'student':'Mike','year':2}]
pd.DataFrame(l)
# Out:
#   student  year  marks
# 0    Jack     1    9.8
# 1    Mike     2    NaN

# %%
df=pd.read_csv('Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
arr=np.random.randint(1,100,(10,5))
df=pd.DataFrame(arr,columns=['a','b','c','d','e'])
df
# Out:
#     a   b   c   d   e
# 0  99   2  99  32  52
# 1  19  46  99  53  30
# 2  68  69  71  80  10
# 3   9   8  79  59  97
# 4  31  57  29  85  86
# 5  82   6  22  46  62
# 6  80  65  49  36  68
# 7  67  99  17  65  39
# 8  62  59   9  93  55
# 9  66  72  41  60  76

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=10, step=1),
#  Index(['a', 'b', 'c', 'd', 'e'], dtype='object')]

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.axes[1]
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df=pd.read_csv('Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sal=df['Salary']
sal
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
df.Salary
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
v1=pd.Series([1,np.nan,2,None])
v1
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
data=pd.read_csv('Salary_Data_Null.csv')
data
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 0      Alex  45.0   10000       BBA    Manager     1     NaN
# 1       Tom   NaN   50000       Bca    Analyst     2   India
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 5       Bob   NaN   40000       MCA  Developer     1     NaN
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
data.isnull().sum()
# Out:
# Name          0
# Age           2
# Salary        0
# Education     0
# Occupation    0
# Rank          0
# Address       2
# dtype: int64

# %%
data.isnull()
# Out:
#     Name    Age  Salary  Education  Occupation   Rank  Address
# 0  False  False   False      False       False  False     True
# 1  False   True   False      False       False  False    False
# 2  False  False   False      False       False  False    False
# 3  False  False   False      False       False  False    False
# 4  False  False   False      False       False  False    False
# 5  False   True   False      False       False  False     True
# 6  False  False   False      False       False  False    False

# %%
data.notnull()
# Out:
#    Name    Age  Salary  Education  Occupation  Rank  Address
# 0  True   True    True       True        True  True    False
# 1  True  False    True       True        True  True     True
# 2  True   True    True       True        True  True     True
# 3  True   True    True       True        True  True     True
# 4  True   True    True       True        True  True     True
# 5  True  False    True       True        True  True    False
# 6  True   True    True       True        True  True     True

# %%
data.dropna()
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
data.dropna(axis=1)
# Out:
#        Name  Salary Education Occupation  Rank
# 0      Alex   10000       BBA    Manager     1
# 1       Tom   50000       Bca    Analyst     2
# 2    Michel   50000       MBA    Manager     3
# 3      Hans   70000       PHD  Professor     3
# 4  Billiana   30000       MBA       Head     4
# 5       Bob   40000       MCA  Developer     1
# 6       Joy     821       BBA    Manager     2

# %%
data.dropna(how='all')
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 0      Alex  45.0   10000       BBA    Manager     1     NaN
# 1       Tom   NaN   50000       Bca    Analyst     2   India
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 5       Bob   NaN   40000       MCA  Developer     1     NaN
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
#drop age column
data.drop(columns='Age')
# Out:
#        Name  Salary Education Occupation  Rank Address
# 0      Alex   10000       BBA    Manager     1     NaN
# 1       Tom   50000       Bca    Analyst     2   India
# 2    Michel   50000       MBA    Manager     3   China
# 3      Hans   70000       PHD  Professor     3   Japan
# 4  Billiana   30000       MBA       Head     4      UK
# 5       Bob   40000       MCA  Developer     1     NaN
# 6       Joy     821       BBA    Manager     2     USA

# %%
#drop rank column
data.drop(columns='Rank')
# Out:
#        Name   Age  Salary Education Occupation Address
# 0      Alex  45.0   10000       BBA    Manager     NaN
# 1       Tom   NaN   50000       Bca    Analyst   India
# 2    Michel  30.0   50000       MBA    Manager   China
# 3      Hans  22.0   70000       PHD  Professor   Japan
# 4  Billiana  28.0   30000       MBA       Head      UK
# 5       Bob   NaN   40000       MCA  Developer     NaN
# 6       Joy  50.0     821       BBA    Manager     USA

# %%
#takes 0 where is null
data.fillna(0)
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 0      Alex  45.0   10000       BBA    Manager     1       0
# 1       Tom   0.0   50000       Bca    Analyst     2   India
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 5       Bob   0.0   40000       MCA  Developer     1       0
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
#takes previous value wherever is null(forward fill)
data.fillna(method='ffill')
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 0      Alex  45.0   10000       BBA    Manager     1     NaN
# 1       Tom  45.0   50000       Bca    Analyst     2   India
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 5       Bob  28.0   40000       MCA  Developer     1      UK
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
#back fill to propagate next values
data.fillna(method='bfill')
# Out:
#        Name   Age  Salary Education Occupation  Rank Address
# 0      Alex  45.0   10000       BBA    Manager     1   India
# 1       Tom  30.0   50000       Bca    Analyst     2   India
# 2    Michel  30.0   50000       MBA    Manager     3   China
# 3      Hans  22.0   70000       PHD  Professor     3   Japan
# 4  Billiana  28.0   30000       MBA       Head     4      UK
# 5       Bob  50.0   40000       MCA  Developer     1     USA
# 6       Joy  50.0     821       BBA    Manager     2     USA

# %%
import pandas as pd
data=pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data['annual_data']=data['Salary']*12
data
# Out:
#     YearsExperience    Salary  annual_data
# 0               1.1   39343.0     472116.0
# 1               1.3   46205.0     554460.0
# 2               1.5   37731.0     452772.0
# 3               2.0   43525.0     522300.0
# 4               2.2   39891.0     478692.0
# 5               2.9   56642.0     679704.0
# 6               3.0   60150.0     721800.0
# 7               3.2   54445.0     653340.0
# 8               3.2   64445.0     773340.0
# 9               3.7   57189.0     686268.0
# 10              3.9   63218.0     758616.0
# 11              4.0   55794.0     669528.0
# 12              4.0   56957.0     683484.0
# 13              4.1   57081.0     684972.0
# 14              4.5   61111.0     733332.0
# 15              4.9   67938.0     815256.0
# 16              5.1   66029.0     792348.0
# 17              5.3   83088.0     997056.0
# 18              5.9   81363.0     976356.0
# 19              6.0   93940.0    1127280.0
# 20              6.8   91738.0    1100856.0
# ...

# %%
data.to_csv('Salary_update.csv')
data.to_dict()
# Out:
# {'YearsExperience': {0: 1.1,
#   1: 1.3,
#   2: 1.5,
#   3: 2.0,
#   4: 2.2,
#   5: 2.9,
#   6: 3.0,
#   7: 3.2,
#   8: 3.2,
#   9: 3.7,
#   10: 3.9,
#   11: 4.0,
#   12: 4.0,
#   13: 4.1,
#   14: 4.5,
#   15: 4.9,
#   16: 5.1,
#   17: 5.3,
#   18: 5.9,
#   19: 6.0,
#   20: 6.8,
#   21: 7.1,
#   22: 7.9,
#   23: 8.2,
#   24: 8.7,
#   25: 9.0,
#   26: 9.5,
#   27: 9.6,
#   28: 10.3,
#   29: 10.5},
#  'Salary': {0: 39343.0,
#   1: 46205.0,
#   2: 37731.0,
#   3: 43525.0,
#   4: 39891.0,
#   5: 56642.0,
#   6: 60150.0,
#   7: 54445.0,
#   8: 64445.0,
#   9: 57189.0,
#   10: 63218.0,
#   11: 55794.0,
#   12: 56957.0,
#   13: 57081.0,
#   14: 61111.0,
#   15: 67938.0,
#   16: 66029.0,
#   17: 83088.0,
#   18: 81363.0,
#   19: 93940.0,
#   20: 91738.0,
#   21: 98273.0,
#   22: 101302.0,
#   23: 113812.0,
#   24: 109431.0,
#   25: 105582.0,
#   26: 116969.0,
#   27: 112635.0,
#   28: 122391.0,
#   29: 121872.0},
#  'annual_data': {0: 472116.0,
#   1: 554460.0,
#   2: 452772.0,
# ...

# %%
d=pd.read_csv('Occupation.csv')
d.head()
# Out:
#        Name   Age  Salary Education Occupation  Rank
# 0      Alex  45.0   10000       BBA    Manager     1
# 1       Tom   NaN   50000       Bca    Analyst     2
# 2    Michel  30.0   50000       MBA    Manager     3
# 3      Hans  22.0   70000       PHD  Professor     3
# 4  Billiana  28.0   30000       MBA       Head     4

# %%
dd=d.set_index('Education')
dd
# Out:
#                Name   Age  Salary Occupation  Rank
# Education
# BBA            Alex  45.0   10000    Manager     1
# Bca             Tom   NaN   50000    Analyst     2
# MBA          Michel  30.0   50000    Manager     3
# PHD            Hans  22.0   70000  Professor     3
# MBA        Billiana  28.0   30000       Head     4
# MCA             Bob   NaN   40000  Developer     1
# BBA             Joy  50.0     821    Manager     2

# %%
dd1=d.set_index(['Occupation','Name'])
dd1
# Out:
#                       Age  Salary Education  Rank
# Occupation Name
# Manager    Alex      45.0   10000       BBA     1
# Analyst    Tom        NaN   50000       Bca     2
# Manager    Michel    30.0   50000       MBA     3
# Professor  Hans      22.0   70000       PHD     3
# Head       Billiana  28.0   30000       MBA     4
# Developer  Bob        NaN   40000       MCA     1
# Manager    Joy       50.0     821       BBA     2

# %%
dd1.sort_values('Name')
# Out:
#                       Age  Salary Education  Rank
# Occupation Name
# Manager    Alex      45.0   10000       BBA     1
# Head       Billiana  28.0   30000       MBA     4
# Developer  Bob        NaN   40000       MCA     1
# Professor  Hans      22.0   70000       PHD     3
# Manager    Joy       50.0     821       BBA     2
#            Michel    30.0   50000       MBA     3
# Analyst    Tom        NaN   50000       Bca     2

# %%
dd1.sort_values('Education')
# Out:
#                       Age  Salary Education  Rank
# Occupation Name
# Manager    Alex      45.0   10000       BBA     1
#            Joy       50.0     821       BBA     2
# Analyst    Tom        NaN   50000       Bca     2
# Manager    Michel    30.0   50000       MBA     3
# Head       Billiana  28.0   30000       MBA     4
# Developer  Bob        NaN   40000       MCA     1
# Professor  Hans      22.0   70000       PHD     3

# %%
d.sort_index()
# Out:
#        Name   Age  Salary Education Occupation  Rank
# 0      Alex  45.0   10000       BBA    Manager     1
# 1       Tom   NaN   50000       Bca    Analyst     2
# 2    Michel  30.0   50000       MBA    Manager     3
# 3      Hans  22.0   70000       PHD  Professor     3
# 4  Billiana  28.0   30000       MBA       Head     4
# 5       Bob   NaN   40000       MCA  Developer     1
# 6       Joy  50.0     821       BBA    Manager     2

# %%
data.describe()
# Out:
#        YearsExperience         Salary   annual_data
# count        30.000000      30.000000  3.000000e+01
# mean          5.313333   76003.000000  9.120360e+05
# std           2.837888   27414.429785  3.289732e+05
# min           1.100000   37731.000000  4.527720e+05
# 25%           3.200000   56720.750000  6.806490e+05
# 50%           4.700000   65237.000000  7.828440e+05
# 75%           7.700000  100544.750000  1.206537e+06
# max          10.500000  122391.000000  1.468692e+06

# %%
data.count()
# Out:
# YearsExperience    30
# Salary             30
# annual_data        30
# dtype: int64

# %%
newdata=pd.read_csv('Salary_Data_Null.csv')
newdata.count()
# Out:
# Name          7
# Age           5
# Salary        7
# Education     7
# Occupation    7
# Rank          7
# Address       5
# dtype: int64

# %%
data=pd.read_csv('age_weight.csv')
data
# Out:
#    Age(months)  Height(inches)  Weight(pounds)
# 0          191            62.5           112.5
# 1          160            62.0            94.5
# 2          157            64.5           123.5

# %%
data.corr()
# Out:
#                 Age(months)  Height(inches)  Weight(pounds)
# Age(months)        1.000000       -0.401583        0.058664
# Height(inches)    -0.401583        1.000000        0.890687
# Weight(pounds)     0.058664        0.890687        1.000000

# %%
data.cov()
# Out:
#                 Age(months)  Height(inches)  Weight(pounds)
# Age(months)      354.333333          -10.00       16.166667
# Height(inches)   -10.000000            1.75       17.250000
# Weight(pounds)    16.166667           17.25      214.333333

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'key1':['a','a','b','b','a'],
                'data1':np.random.randint(100,200,5),
                'data2':np.random.randint(200,300,5)})
df
# Out:
#   key1  data1  data2
# 0    a    115    247
# 1    a    184    229
# 2    b    143    244
# 3    b    165    273
# 4    a    162    242

# %%
df.groupby('key1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3784\728375896.py in <module>
# ----> 1 df.groupby('key1')
#
# NameError: name 'df' is not defined
